# %%
import sys
import time
import matplotlib
from matplotlib import pyplot, markers
from matplotlib.lines import Line2D
from matplotlib.transforms import Affine2D
import plotly.graph_objects as go
import plotly.tools as tools

# %%
# Mapping of xplot colours; these are from colorbrewer2.org
COLOURS = {"white":"#1b9e77",
           "black": "#666666",
           "orange": "#a6761d",
           "green": "#66a61e",
           "yellow": "#e6ab02",
           "red": "#d95f02",
           "blue": "#386cb0",
           "purple": "#7570b3",
}

# Mapping xplot markers to matplotlib markers
MARKERS = {'darrow': markers.CARETDOWN,
           'uarrow': markers.CARETUP,
           'box': 's',
           'dot': '.',
           'utick': markers.TICKUP,
           'dtick': markers.TICKDOWN,
           'htick': '_',
           'diamond': 'D'}

# Mapping xplot markers to plotly markers
MARKERS = {'darrow': 'triangle-down',
           'uarrow': 'triangle-up',
           'box': 'square',
           'dot': 'circle',
           'utick': 'hexagon',
           'dtick': 'hexagon',
           'htick': 'hexagon',
           'diamond': 'diamond'}

# %%
def plot_xplot(filename):
    fp = open(filename, "r")
    #fig = pyplot.figure()
    #ax = fig.gca()
    col = "black"
    
    fig = go.Figure()

    # Strategy for markers: Collect all markers of the same style and colour in
    # a list which is then plotted using axes.plot() at the end. This dict and
    # helper function does that.
    markers = {}
    def add_marker(col,m,parts):
        if len(parts) == 4 and parts[3] in COLOURS:
            col = parts[3]
        k = col,m
        x,y = map(float,parts[1:3])
        if k in markers:
            markers[k][0].append(x)
            markers[k][1].append(y)
        else:
            markers[k] = ([x],[y])

            
    # Similarly as for makers, we keep lines mapped by colour and try to combine
    # them if we have several line segments that share points
    lines = {}
    def add_line(col,parts):
        x1,y1,x2,y2 = map(float, parts[1:])
        if not col in lines:
            lines[col] = [([x1,x2],[y1,y2])]
        else:
            found = False
            for l in lines[col][-5:]:
                if l[0][-1] == x1 and l[1][-1] == y1:
                    l[0].append(x2)
                    l[1].append(y2)
                    found = True
                    break
            if not found:
                lines[col].append(([x1,x2],[y1,y2]))


    # Parse the xplot command lines
    for line in fp:
        line = line.strip()
        parts = line.split()
        if line.startswith("timeval"):
            # This just sets a data type; we don't care
            pass

        # title, xlabel and ylabel has the value on the following line
        elif line == "title":
            fig.update_layout(title=next(fp).strip())
        elif line == "xlabel":
            fig.update_layout(xaxis_title=next(fp).strip())
        elif line == "ylabel":
            fig.update_layout(yaxis_title=next(fp).strip())

        # A colour name on a line sets the current colour
        elif line in COLOURS:
            col = line

        # Lines are defined as 'line x1 y1 x2 y2'
        elif parts[0] == "line":
            x1,y1,x2,y2 = map(float, parts[1:])
            add_line(col,parts)

        # Text above or to the right specifies coordinates with the string on
        # the next line
        
        elif parts[0] in ("atext","rtext","ltext"):
            text = next(fp).strip()
            x,y = map(float, parts[1:3])
            kwargs = {'ha': 'center', 'va':'center', 'color': COLOURS[col],
                      'textcoords':'offset points'}
            theta=0
            offset = (0,5)
            if len(parts) == 4 and parts[3] in COLOURS:
                kwargs['color'] = COLOURS[parts[3]]
            if parts[0] == "rtext":
                kwargs['ha'] = 'left'
                offset = (2,0)
            elif parts[0] == "ltext":
                kwargs['ha'] = 'right'
                offset = (-2,0)
            fig.add_annotation(text=text,x=x,y=y)

        # Markers are specified as 'marker x y'
        elif parts[0] in MARKERS.keys():
            add_marker(col,MARKERS[parts[0]],parts)

        # We are done, let's draw
        elif line == "go":
            break
        else:
            print("Unknown: %s" % line)

    # Draw the lines
    for c,ll in lines.items(): 
        # Horizontal line shape
        for x,y in ll:
            fig.add_trace(go.Scatter(x=x,y=y, name=COLOURS[c],line=dict(color=COLOURS[c])))

    # Draw the markers
    for (c,m),(x,y) in markers.items():
        fig.add_trace(go.Scatter(x=x,y=y, mode='markers', name=COLOURS[c], marker=dict(color=COLOURS[c])))
        fig['data'][0]['marker']['symbol'] = m
                      
    #ax.autoscale_view()
    fig.update_layout(showlegend=False)
    fig.show()
    return fig

# %%
fig = plot_xplot("xplot_graphs/b2a_tsg.xpl")
# Out:
# <div>
#
#
#             <div id="5306811d-97c6-4ece-95ed-e0b640e91550" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5306811d-97c6-4ece-95ed-e0b640e91550")) {
#                     Plotly.newPlot(
#                         '5306811d-97c6-4ece-95ed-e0b640e91550',
#                         [{"line": {"color": "#a6761d"}, "marker": {"symbol": "square"}, "name": "#a6761d", "type": "scatter", "x": [1580441351.461209, 1580441351.461209], "y": [3511987339.0, 3511987340.0]}, {"line": {"color": "#a6761d"}, "name": "#a6761d", "type": "scatter", "x": [1580441352.966218, 1580441352.966218], "y": [3515165057.0, 3515165058.0]}, {"line": {"color": "#66a61e"}, "name": "#66a61e", "type": "scatter", "x": [1580441351.461257, 1580441351.461673, 1580441351.607064, 1580441351.607064, 1580441351.608651, 1580441351.72962, 1580441351.72962, 1580441351.729736, 1580441351.729736, 1580441351.850688, 1580441351.850688, 1580441351.851165, 1580441351.971916, 1580441351.971916, 1580441351.971937, 1580441351.971937, 1580441351.97236, 1580441351.97236, 1580441351.9724, 1580441351.9724, 1580441352.094423, 1580441352.094423, 1580441352.094479, 1580441352.094479, 1580441352.094685, 1580441352.094685, 1580441352.094791, 1580441352.094791, 1580441352.094959, 1580441352.094959, 1580441352.095118, 1580441352.095118, 1580441352.095355, 1580441352.095355, 1580441352.098588, 1580441352.098588, 1580441352.098685, 1580441352.098685, 1580441352.214941, 1580441352.214941, 1580441352.